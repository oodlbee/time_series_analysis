# %% [markdown]
# # Анализ заболеваемости короновирусом

# %% [markdown]
# Оценка пиков заболеваемости при помощи апрпроксимации фукнции заболеваемости рядом Фурье

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('coron_data.csv', sep=';', parse_dates=['DateTime'])
print(df.head())
# Out:
#     DateTime  Заражений за день  Выздоровлений за день  Смертей за день
# 0 2020-03-12                 34                      0                0
# 1 2020-03-13                 11                      0                0
# 2 2020-03-14                 14                      0                0
# 3 2020-03-15                  4                      3                0
# 4 2020-03-16                 28                      2                0

# %%
df = df.rename(columns={
    'Заражений за день' : 'Infect',
    'Выздоровлений за день' : 'Recovery',
    'Смертей за день' : 'Death'
})
df.head()
# Out:
#     DateTime  Infect  Recovery  Death
# 0 2020-03-12      34         0      0
# 1 2020-03-13      11         0      0
# 2 2020-03-14      14         0      0
# 3 2020-03-15       4         3      0
# 4 2020-03-16      28         2      0

# %%
plt.figure(figsize=(10, 5))
plt.plot(df.DateTime, df.Infect)
plt.title("Заражение по дате")
plt.show()

# %% [markdown]
# Оценим высокочастотную периодичность функции прироста новых случаев заболевания (график "Прирост по дням")

# %%
df.dtypes
# Out:
# DateTime    datetime64[ns]
# Infect               int64
# Recovery             int64
# Death                int64
# dtype: object

# %% [markdown]
# ### Переведем тип datetime64 даты в числовый тип (в дни)

# %%
df.DateTime.shape[0]
df.head()
# Out:
#     DateTime  Infect  Recovery  Death
# 0 2020-03-12      34         0      0
# 1 2020-03-13      11         0      0
# 2 2020-03-14      14         0      0
# 3 2020-03-15       4         3      0
# 4 2020-03-16      28         2      0

# %%
date_list = []
for i in range(df.DateTime.shape[0]):
    date_list.append((df.DateTime[i] - df.DateTime[0])/  np.timedelta64(1, 'D'))
df_day = df.copy()
df_day.DateTime = date_list
df_day.head()
# Out:
#    DateTime  Infect  Recovery  Death
# 0       0.0      34         0      0
# 1       1.0      11         0      0
# 2       2.0      14         0      0
# 3       3.0       4         3      0
# 4       4.0      28         2      0

# %% [markdown]
# ### Сделаем преобразование Фурье

# %%
new_y = np.zeros(df_day.Infect.shape)
spec = np.fft.fft(df_day.Infect)
cn = np.abs((spec.real**2 + spec.imag**2)**(1/2))
theta = np.angle(spec)
Ts = np.mean(np.diff(df_day.DateTime))
fs = 1 / Ts
fs_day = fs * 60 * 60 * 24
Ts, fs
# Out:
# (1.0, 1.0)

# %% [markdown]
# Частота дискретизации получилась 1 Гц (мы считаем в днях, так что это один день), ожидаемо.

# %%
for n in range(len(new_y)):
    new_y += 2 * cn[n] * np.cos(2 * np.pi * fs/len(new_y) * n * df_day.DateTime  + theta[n])

# %%
plt.plot(new_y / np.max(new_y))
plt.plot(df.Infect / np.max(df.Infect))
plt.legend(("Изначальная функция","Преобразование Фурье"))
plt.show()

# %% [markdown]
# Графики совпали, возьмем меньший n, чтобы посмотреть, как они не совпадают

# %%
new_y = np.zeros(df_day.Infect.shape)
spec = np.fft.fft(df_day.Infect)
cn = np.abs((spec.real**2 + spec.imag**2)**(1/2))
theta = np.angle(spec)
Ts = np.mean(np.diff(df_day.DateTime))
fs = 1 / Ts
fs_day = fs * 60 * 60 * 24
Ts, fs
for n in range(int(len(new_y)/2)):
    new_y += 2 * cn[n] * np.cos(2 * np.pi * fs/len(new_y) * n * df_day.DateTime  + theta[n])
plt.plot((new_y - new_y.mean()) / np.max(new_y))
plt.plot((df.Infect - df.Infect.mean()) / np.max(df.Infect))
plt.legend(("Изначальная функция","Преобразование Фурье"))
plt.show()

# %% [markdown]
# Видим, то при изменении уменьшении аппроксимации видим, что функции начинают отличаться друг от друга

# %% [markdown]
# ### Найдем частоту занесения данных в таблицу

# %% [markdown]
# Для этого выведем спектр сигнала, и с помощью него найдем высокую составляющую сигнала

# %%
df_cut = df_day[350:400]
dat = df_cut.Infect - np.mean(df_cut.Infect)
dat = dat/ np.max(dat)
plt.figure(figsize=(10,5))
plt.plot(df_cut.DateTime, dat)
plt.title("График малого промежутка времени")
plt.show()

# %%
spectra = np.fft.fft(dat)
dens = np.abs(spectra)**2
f = np.asarray([2*np.pi * fs/len(dat) * i for i in range(int(len(dat)))])
plt.plot(f, dens)
plt.title("Спектр этого промежутка")
plt.show()

# %%
f1 = f[np.argmax(dens[:-10])]
print(f'Период T = {1/f1} дней\nэто скорее всего период добавления данных в таблицу')
# Out:
# Период T = 7.957747154594767 дней
# это скорее всего период добавления данных в таблицу

# %% [markdown]
# ### Определим даты, соответствующие наивысшим точкам каждой волны

# %% [markdown]
# Для этого аппроксимируем функцию через преобразование Фурье

# %%
new_y = np.zeros(df_day.Infect.shape)
spec = np.fft.fft(df_day.Infect)
cn = np.abs((spec.real**2 + spec.imag**2)**(1/2))
theta = np.angle(spec)
Ts = np.mean(np.diff(df_day.DateTime))
fs = 1 / Ts
fs_day = fs * 60 * 60 * 24
Ts, fs
for n in range(11):
    new_y += 2 * cn[n] * np.cos(2 * np.pi * fs/len(new_y) * n * df_day.DateTime  + theta[n])
plt.plot((new_y - new_y.mean()) / np.max(new_y))
plt.plot((df.Infect - df.Infect.mean()) / np.max(df.Infect))
plt.legend(("Преобразование Фурье","Изначальная функция"))
plt.show()

# %% [markdown]
# Только на 11ой гармонике мы добились частичного совпадения по максимумам

# %%
dif = np.diff(new_y)
dif_change_sign_arr = ((np.roll(np.sign(dif), 1) - np.sign(dif)) != 0).astype(int)
dif_change_sign_indc = np.where(dif_change_sign_arr)

# %%
dif = np.diff(new_y)
plt.plot(new_y/ max(new_y))
plt.plot(dif/ max(dif))
plt.plot(np.zeros(len(dif)))
plt.scatter(dif_change_sign_indc, np.zeros(len(dif_change_sign_indc[0])))

# %% [markdown]
# Первый пик соответствует максимуму, значит берем четные пики для оценки максимумов

# %%
max_indeces = dif_change_sign_indc[0][::2]
max_indeces
# Out:
# array([ 40, 119, 297, 399, 496, 595, 705, 816, 913])

# %%
max_el = np.take(new_y, max_indeces)
max_el
# Out:
# 40     3.131598e+07
# 119    3.209294e+07
# 297    5.006582e+07
# 399    3.457807e+07
# 496    5.215147e+07
# 595    6.781557e+07
# 705    1.471798e+08
# 816    3.409257e+07
# 913    7.243626e+07
# Name: DateTime, dtype: float64

# %%
plt.plot(range(982), (df.Infect - df.Infect.mean())/max(df.Infect), color='c')
plt.scatter(max_indeces, ((df.Infect[max_indeces] - df.Infect.mean())/max(df.Infect)), color='r')

# %% [markdown]
# Отбросим точки, которые явно не соответсвуют пикам. Это точки 2,4,8

# %%
max_el
# Out:
# 40     3.131598e+07
# 119    3.209294e+07
# 297    5.006582e+07
# 399    3.457807e+07
# 496    5.215147e+07
# 595    6.781557e+07
# 705    1.471798e+08
# 816    3.409257e+07
# 913    7.243626e+07
# Name: DateTime, dtype: float64

# %%
res_max_el = max_el.drop([119, 399, 816])
res_max_el
# Out:
# 40     3.131598e+07
# 297    5.006582e+07
# 496    5.215147e+07
# 595    6.781557e+07
# 705    1.471798e+08
# 913    7.243626e+07
# Name: DateTime, dtype: float64

# %%
plt.plot(range(982), (df.Infect - df.Infect.mean())/max(df.Infect), color='c')
plt.scatter(res_max_el.index, ((df.Infect[res_max_el.index] - df.Infect.mean())/max(df.Infect)), color='r')

# %% [markdown]
# Переведем время в дату

# %%
indeces = list(res_max_el.index)

# %%
dates_of_max = pd.DataFrame(df.loc[indeces].reset_index(drop=True))
dates_of_max.index +=1

# %%
dates_of_max
# Out:
#     DateTime  Infect  Recovery  Death
# 1 2020-04-21    5642       427     51
# 2 2021-01-03   24150     19847    504
# 3 2021-07-21   23704     22584    783
# 4 2021-10-28   40096     29318   1159
# 5 2022-02-15  166631    137881    704
# 6 2022-09-11   52829     37288     86

# %% [markdown]
# ### Вывод

# %% [markdown]
# Мы аппроксимировали функцию заболеваемости от короновируса и выделили основные пики заболевания на 11ой гармонике.
