# %% [markdown]
# # Предсказание ЭКГ сигнала

# %% [markdown]
# Проверим, насколько адекватно работает LSTM на таких быстродействующих сигналах как ЭКГ

# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
import math
import tensorflow as tf
from scipy import signal
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
dataframe = read_csv('200.csv', usecols=[1], engine='python')
dataframe.head()
# Out:
#    'MLII'
# 0    1094
# 1    1094
# 2    1094
# 3    1094
# 4    1094

# %%
plt.plot(dataframe)
plt.xlim([3000,5000])
plt.show()

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
# load the dataset
dataset = dataframe.values
dataset = dataset.astype('float32')

# %%
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %%
# split into train and test sets
dataset_test = dataset[0:5000]
train_size = int(len(dataset_test) * 0.67)
test_size = len(dataset_test) - train_size
train, test = dataset_test[0:train_size,:], dataset_test[train_size:len(dataset_test),:]

# %%
# reshape into X=t and Y=t+1
look_back = 10
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(64, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=50, batch_size=1, verbose=2)
# Out:
# Epoch 1/50
# 3339/3339 - 5s - loss: 0.0032 - 5s/epoch - 1ms/step
# Epoch 2/50
# 3339/3339 - 4s - loss: 4.0476e-04 - 4s/epoch - 1ms/step
# Epoch 3/50
# 3339/3339 - 4s - loss: 3.0165e-04 - 4s/epoch - 1ms/step
# Epoch 4/50
# 3339/3339 - 4s - loss: 2.1838e-04 - 4s/epoch - 1ms/step
# Epoch 5/50
# 3339/3339 - 4s - loss: 1.9138e-04 - 4s/epoch - 1ms/step
# Epoch 6/50
# 3339/3339 - 4s - loss: 1.7090e-04 - 4s/epoch - 1ms/step
# Epoch 7/50
# 3339/3339 - 4s - loss: 1.5093e-04 - 4s/epoch - 1ms/step
# Epoch 8/50
# 3339/3339 - 4s - loss: 1.3430e-04 - 4s/epoch - 1ms/step
# Epoch 9/50
# 3339/3339 - 4s - loss: 1.2244e-04 - 4s/epoch - 1ms/step
# Epoch 10/50
# 3339/3339 - 4s - loss: 1.1655e-04 - 4s/epoch - 1ms/step
# Epoch 11/50
# 3339/3339 - 4s - loss: 1.1163e-04 - 4s/epoch - 1ms/step
# Epoch 12/50
# 3339/3339 - 4s - loss: 1.0398e-04 - 4s/epoch - 1ms/step
# Epoch 13/50
# 3339/3339 - 4s - loss: 1.0016e-04 - 4s/epoch - 1ms/step
# Epoch 14/50
# 3339/3339 - 4s - loss: 9.6043e-05 - 4s/epoch - 1ms/step
# ...

# %%
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# Out:
# ...
# 52/52 [==============================] - 0s 1ms/step

# %%
# invert predictions

trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])

testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# %%
# calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))

testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 5.54 RMSE
# Test Score: 4.82 RMSE

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset_test)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

testPredictPlot = np.empty_like(dataset_test)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset_test)-1, :] = testPredict

# %%
plt.plot(scaler.inverse_transform(dataset))
plt.plot(testPredictPlot)
plt.plot(trainPredictPlot)
plt.xlim([2000,6000])
plt.show()

# %% [markdown]
# В коде выше предсказывается значение теста, которое мы и даем на обработку. Новые значение не предсказываются. Предскажем новые значения.

# %%
N = 300
X = trainX[-look_back:]

prediction = np.empty((N, 1), dtype='float32')
for i in range(N):
    pred_val = model.predict(X[-look_back:])
    X = np.vstack([X[:,0,:], pred_val.T])
    X = np.reshape(X, (X.shape[0], 1, X.shape[1]))
    prediction[i][0] = pred_val[-1][0]
# Out:
# ...
# 1/1 [==============================] - 0s 22ms/step

# %%
prediction = scaler.inverse_transform(prediction)

# %%
test_prediction = np.empty_like(dataset_test)
test_prediction[:, :] = np.nan
test_prediction[len(trainPredict):len(trainPredict)+len(prediction), :] = prediction

# %%
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(test_prediction)
plt.xlim([3200,3700])
plt.show()

# %% [markdown]
# ## Попробуем  использовать несколько LSTM в модели

# %%
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(
    50,  activation='relu', return_sequences=True, input_shape=(1, look_back)
))
model.add(LSTM(50, activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=50, batch_size=1, verbose=2)
# Out:
# Epoch 1/50
# 3339/3339 - 7s - loss: 0.0031 - 7s/epoch - 2ms/step
# Epoch 2/50
# 3339/3339 - 5s - loss: 3.8855e-04 - 5s/epoch - 1ms/step
# Epoch 3/50
# 3339/3339 - 5s - loss: 2.8541e-04 - 5s/epoch - 1ms/step
# Epoch 4/50
# 3339/3339 - 5s - loss: 2.3445e-04 - 5s/epoch - 1ms/step
# Epoch 5/50
# 3339/3339 - 5s - loss: 2.0045e-04 - 5s/epoch - 1ms/step
# Epoch 6/50
# 3339/3339 - 5s - loss: 1.7624e-04 - 5s/epoch - 1ms/step
# Epoch 7/50
# 3339/3339 - 5s - loss: 1.5739e-04 - 5s/epoch - 1ms/step
# Epoch 8/50
# 3339/3339 - 5s - loss: 1.4693e-04 - 5s/epoch - 1ms/step
# Epoch 9/50
# 3339/3339 - 5s - loss: 1.3396e-04 - 5s/epoch - 1ms/step
# Epoch 10/50
# 3339/3339 - 5s - loss: 1.3696e-04 - 5s/epoch - 1ms/step
# Epoch 11/50
# 3339/3339 - 6s - loss: 1.2953e-04 - 6s/epoch - 2ms/step
# Epoch 12/50
# 3339/3339 - 5s - loss: 1.1641e-04 - 5s/epoch - 2ms/step
# Epoch 13/50
# 3339/3339 - 5s - loss: 1.1564e-04 - 5s/epoch - 2ms/step
# Epoch 14/50
# 3339/3339 - 5s - loss: 1.1053e-04 - 5s/epoch - 2ms/step
# ...

# %%
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# Out:
# ...
# 52/52 [==============================] - 0s 2ms/step

# %%
# invert predictions

trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])

testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# %%
# calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))

testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 5.15 RMSE
# Test Score: 4.44 RMSE

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset_test)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

testPredictPlot = np.empty_like(dataset_test)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset_test)-1, :] = testPredict

# %%
plt.plot(scaler.inverse_transform(dataset))
plt.plot(testPredictPlot)
plt.plot(trainPredictPlot)
plt.xlim([2000,6000])
plt.show()

# %%
N = 300
X = trainX[-look_back:]

prediction = np.empty((N, 1), dtype='float32')
for i in range(N):
    pred_val = model.predict(X[-look_back:])
    X = np.vstack([X[:,0,:], pred_val.T])
    X = np.reshape(X, (X.shape[0], 1, X.shape[1]))
    prediction[i][0] = pred_val[-1][0]
# Out:
# ...
# 1/1 [==============================] - 0s 27ms/step

# %%
prediction = scaler.inverse_transform(prediction)

# %%
test_prediction = np.empty_like(dataset_test)
test_prediction[:, :] = np.nan
test_prediction[len(trainPredict):len(trainPredict)+len(prediction), :] = prediction

# %%
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(test_prediction)
plt.xlim([3300,3450])
plt.show()

# %% [markdown]
# Результат получился плохой

# %% [markdown]
# # Вывод

# %% [markdown]
# LSTM не подходит для предсказания сигнала ЭКГ. Эта нейронная сеть подходит больше для предсказания будущей тенденции, основываясь на сигнале.
